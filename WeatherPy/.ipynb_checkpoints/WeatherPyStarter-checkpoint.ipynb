# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.
#
#
# *In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator.
#
# *To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy),
#
# *the [OpenWeatherMap API](https://openweathermap.org/api),
#
# *and a little common sense to create a representative model of weather across world cities.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %%
cities_df = pd.DataFrame(cities, columns = ['city'])
cities_df
# Out:
#               city
# 0       bredasdorp
# 1          rikitea
# 2      east london
# 3        busselton
# 4    leningradskiy
# ..             ...
# 606       tessalit
# 607     vezirkopru
# 608       koutiala
# 609   christchurch
# 610      kafanchan
#
# [611 rows x 1 columns]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

weather_query_url = f"{base_url}&APPID={weather_api_key}"


#print(weather_query_url)

# %%
# Get weather data
# use iterrows to iterate through pandas dataframe
temperature = []
index = []

cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []


Error_count = 0
for index, row in cities_df.iterrows():

    # get city name from df
    city_name = row['city']
    
    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {city_name}.")
    weather_json = requests.get(weather_query_url + "&q="+ city_name +"&units="+units).json()
    #pprint(weather_json)
    
    ##extract results
    try:
        #Cloudiness
        cloudiness = weather_json["clouds"]["all"]
        cities_df.loc[index, 'cloudiness'] = cloudiness
        #Country
        country = weather_json["sys"]["country"]
        cities_df.loc[index, 'country'] = country
        #date
        date = weather_json["dt"]
        cities_df.loc[index, 'date'] = date
        #humidity
        humidity = weather_json["main"]["humidity"]
        cities_df.loc[index, 'humidity'] = humidity
        #latitude
        latitude = weather_json["coord"]["lat"]
        cities_df.loc[index, 'latitude'] = latitude
        #longitude
        longitude = weather_json["coord"]["lon"]
        cities_df.loc[index, 'longitude'] = longitude
        #Max Temp
        max_temp = weather_json["main"]["temp_max"]
        cities_df.loc[index, 'max_temp'] = max_temp
        #wind_speed
        wind_speed = weather_json["wind"]["speed"]
        cities_df.loc[index, 'wind_speed'] = wind_speed
        
        
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
    print("------------")
# Out:
# Retrieving Results for Index 0: bredasdorp.
# ------------
# Retrieving Results for Index 1: rikitea.
# ------------
# Retrieving Results for Index 2: east london.
# ------------
# Retrieving Results for Index 3: busselton.
# ------------
# Retrieving Results for Index 4: leningradskiy.
# ------------
# Retrieving Results for Index 5: norman wells.
# ------------
# Retrieving Results for Index 6: upernavik.
# ------------
# Retrieving Results for Index 7: tautira.
# ------------
# Retrieving Results for Index 8: puerto ayora.
# ------------
# Retrieving Results for Index 9: vaini.
# ------------
# Retrieving Results for Index 10: chuy.
# ------------
# Retrieving Results for Index 11: dikson.
# ------------
# Retrieving Results for Index 12: torbay.
# ------------
# Retrieving Results for Index 13: cape town.
# ------------
# Retrieving Results for Index 14: pawai.
# ------------
# Retrieving Results for Index 15: ushuaia.
# ------------
# Retrieving Results for Index 16: katsuura.
# ------------
# Retrieving Results for Index 17: belcesti.
# ------------
# Retrieving Results for Index 18: bluff.
# ------------
# Retrieving Results for Index 19: tibati.
# ------------
# Retrieving Results for Index 20: butaritari.
# ------------
# Retrieving Results for Index 21: tasiilaq.
# ------------
# Retrieving Results for Index 22: killarney.
# ------------
# Retrieving Results for Index 23: ilulissat.
# ------------
# Retrieving Results for Index 24: omutninsk.
# ------------
# Retrieving Results for Index 25: camabatela.
# ------------
# Retrieving Results for Index 26: nikolskoye.
# ------------
# Retrieving Results for Index 27: yellowknife.
# ------------
# Retrieving Results for Index 28: aklavik.
# ------------
# Retrieving Results for Index 29: swellendam.
# ------------
# Retrieving Results for Index 30: khatanga.
# ------------
# Retrieving Results for Index 31: kodiak.
# ------------
# Retrieving Results for Index 32: luderitz.
# ------------
# Retrieving Results for Index 33: san patricio.
# ------------
# Retrieving Results for Index 34: hokota.
# ------------
# Retrieving Results for Index 35: lazaro cardenas.
# ------------
# Retrieving Results for Index 36: saint-philippe.
# ------------
# Retrieving Results for Index 37: nyurba.
# ------------
# Retrieving Results for Index 38: cidreira.
# ------------
# Retrieving Results for Index 39: mar del plata.
# ------------
# Retrieving Results for Index 40: pangnirtung.
# ------------
# Retrieving Results for Index 41: souillac.
# ------------
# Retrieving Results for Index 42: tsihombe.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 43: punta arenas.
# ------------
# Retrieving Results for Index 44: inhambane.
# ------------
# Retrieving Results for Index 45: lata.
# ------------
# Retrieving Results for Index 46: kapaa.
# ------------
# Retrieving Results for Index 47: brekstad.
# ------------
# Retrieving Results for Index 48: teguise.
# ------------
# Retrieving Results for Index 49: arlit.
# ------------
# Retrieving Results for Index 50: cabo san lucas.
# ------------
# Retrieving Results for Index 51: kolpny.
# ------------
# Retrieving Results for Index 52: barentsburg.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 53: kokopo.
# ------------
# Retrieving Results for Index 54: qaanaaq.
# ------------
# Retrieving Results for Index 55: teshie.
# ------------
# Retrieving Results for Index 56: nakamura.
# ------------
# Retrieving Results for Index 57: vaitupu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 58: caravelas.
# ------------
# Retrieving Results for Index 59: iquitos.
# ------------
# Retrieving Results for Index 60: kariba.
# ------------
# Retrieving Results for Index 61: hithadhoo.
# ------------
# Retrieving Results for Index 62: atuona.
# ------------
# Retrieving Results for Index 63: mahebourg.
# ------------
# Retrieving Results for Index 64: tiksi.
# ------------
# Retrieving Results for Index 65: albany.
# ------------
# Retrieving Results for Index 66: hasaki.
# ------------
# Retrieving Results for Index 67: coari.
# ------------
# Retrieving Results for Index 68: hofn.
# ------------
# Retrieving Results for Index 69: whitehorse.
# ------------
# Retrieving Results for Index 70: rawson.
# ------------
# Retrieving Results for Index 71: avarua.
# ------------
# Retrieving Results for Index 72: jamestown.
# ------------
# Retrieving Results for Index 73: mataura.
# ------------
# Retrieving Results for Index 74: hermanus.
# ------------
# Retrieving Results for Index 75: salalah.
# ------------
# Retrieving Results for Index 76: myanaung.
# ------------
# Retrieving Results for Index 77: hilo.
# ------------
# Retrieving Results for Index 78: saint george.
# ------------
# Retrieving Results for Index 79: sapernoye.
# ------------
# Retrieving Results for Index 80: victoria.
# ------------
# Retrieving Results for Index 81: portland.
# ------------
# Retrieving Results for Index 82: dolbeau.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 83: monywa.
# ------------
# Retrieving Results for Index 84: new norfolk.
# ------------
# Retrieving Results for Index 85: taolanaro.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 86: lagoa.
# ------------
# Retrieving Results for Index 87: dong hoi.
# ------------
# Retrieving Results for Index 88: byron bay.
# ------------
# Retrieving Results for Index 89: thompson.
# ------------
# Retrieving Results for Index 90: tharrawaddy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 91: sinnamary.
# ------------
# Retrieving Results for Index 92: grindavik.
# ------------
# Retrieving Results for Index 93: willowmore.
# ------------
# Retrieving Results for Index 94: porto novo.
# ------------
# Retrieving Results for Index 95: port alfred.
# ------------
# Retrieving Results for Index 96: hobart.
# ------------
# Retrieving Results for Index 97: umm jarr.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 98: kavaratti.
# ------------
# Retrieving Results for Index 99: poum.
# ------------
# Retrieving Results for Index 100: ayr.
# ------------
# Retrieving Results for Index 101: goderich.
# ------------
# Retrieving Results for Index 102: calama.
# ------------
# Retrieving Results for Index 103: chagda.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 104: alta floresta.
# ------------
# Retrieving Results for Index 105: hami.
# ------------
# Retrieving Results for Index 106: mys shmidta.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 107: panzhihua.
# ------------
# Retrieving Results for Index 108: vestmannaeyjar.
# ------------
# Retrieving Results for Index 109: kataysk.
# ------------
# Retrieving Results for Index 110: fort nelson.
# ------------
# Retrieving Results for Index 111: soderhamn.
# ------------
# Retrieving Results for Index 112: saint-augustin.
# ------------
# Retrieving Results for Index 113: saldanha.
# ------------
# Retrieving Results for Index 114: port hardy.
# ------------
# Retrieving Results for Index 115: nizhneyansk.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 116: kuala terengganu.
# ------------
# Retrieving Results for Index 117: oranjemund.
# ------------
# Retrieving Results for Index 118: tall kayf.
# ------------
# Retrieving Results for Index 119: anito.
# ------------
# Retrieving Results for Index 120: tuktoyaktuk.
# ------------
# Retrieving Results for Index 121: lebu.
# ------------
# Retrieving Results for Index 122: panorama.
# ------------
# Retrieving Results for Index 123: yerbogachen.
# ------------
# Retrieving Results for Index 124: broome.
# ------------
# Retrieving Results for Index 125: sulangan.
# ------------
# Retrieving Results for Index 126: saskylakh.
# ------------
# Retrieving Results for Index 127: san quintin.
# ------------
# Retrieving Results for Index 128: bonnyville.
# ------------
# Retrieving Results for Index 129: chara.
# ------------
# Retrieving Results for Index 130: kidal.
# ------------
# Retrieving Results for Index 131: codrington.
# ------------
# Retrieving Results for Index 132: kruisfontein.
# ------------
# Retrieving Results for Index 133: mount isa.
# ------------
# Retrieving Results for Index 134: baghdad.
# ------------
# Retrieving Results for Index 135: illoqqortoormiut.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 136: dunedin.
# ------------
# Retrieving Results for Index 137: gandu.
# ------------
# Retrieving Results for Index 138: grand forks.
# ------------
# Retrieving Results for Index 139: ketchikan.
# ------------
# Retrieving Results for Index 140: haibowan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 141: acajutla.
# ------------
# Retrieving Results for Index 142: axim.
# ------------
# Retrieving Results for Index 143: merrill.
# ------------
# Retrieving Results for Index 144: bambous virieux.
# ------------
# Retrieving Results for Index 145: ouadda.
# ------------
# Retrieving Results for Index 146: cap malheureux.
# ------------
# Retrieving Results for Index 147: wexford.
# ------------
# Retrieving Results for Index 148: high prairie.
# ------------
# Retrieving Results for Index 149: itaituba.
# ------------
# Retrieving Results for Index 150: airai.
# ------------
# Retrieving Results for Index 151: payakumbuh.
# ------------
# Retrieving Results for Index 152: safford.
# ------------
# Retrieving Results for Index 153: carnarvon.
# ------------
# Retrieving Results for Index 154: arraial do cabo.
# ------------
# Retrieving Results for Index 155: isangel.
# ------------
# Retrieving Results for Index 156: saint-leu.
# ------------
# Retrieving Results for Index 157: darhan.
# ------------
# Retrieving Results for Index 158: barrow.
# ------------
# Retrieving Results for Index 159: esperance.
# ------------
# Retrieving Results for Index 160: varhaug.
# ------------
# Retrieving Results for Index 161: lyubech.
# ------------
# Retrieving Results for Index 162: ribeira grande.
# ------------
# Retrieving Results for Index 163: trelew.
# ------------
# Retrieving Results for Index 164: bairiki.
# ------------
# Retrieving Results for Index 165: severo-kurilsk.
# ------------
# Retrieving Results for Index 166: ingham.
# ------------
# Retrieving Results for Index 167: northam.
# ------------
# Retrieving Results for Index 168: vila velha.
# ------------
# Retrieving Results for Index 169: qui nhon.
# ------------
# Retrieving Results for Index 170: sao filipe.
# ------------
# Retrieving Results for Index 171: mogadishu.
# ------------
# Retrieving Results for Index 172: ust-tsilma.
# ------------
# Retrieving Results for Index 173: kaohsiung.
# ------------
# Retrieving Results for Index 174: camacha.
# ------------
# Retrieving Results for Index 175: pevek.
# ------------
# Retrieving Results for Index 176: galveston.
# ------------
# Retrieving Results for Index 177: taoudenni.
# ------------
# Retrieving Results for Index 178: doha.
# ------------
# Retrieving Results for Index 179: cairns.
# ------------
# Retrieving Results for Index 180: urazovka.
# ------------
# Retrieving Results for Index 181: cam pha.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 182: palabuhanratu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 183: vagay.
# ------------
# Retrieving Results for Index 184: attawapiskat.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 185: gidole.
# ------------
# Retrieving Results for Index 186: klaksvik.
# ------------
# Retrieving Results for Index 187: burnie.
# ------------
# Retrieving Results for Index 188: yulara.
# ------------
# Retrieving Results for Index 189: jaque.
# ------------
# Retrieving Results for Index 190: alice springs.
# ------------
# Retrieving Results for Index 191: westport.
# ------------
# Retrieving Results for Index 192: provideniya.
# ------------
# Retrieving Results for Index 193: laguna.
# ------------
# Retrieving Results for Index 194: alyangula.
# ------------
# Retrieving Results for Index 195: petropavlovsk-kamchatskiy.
# ------------
# Retrieving Results for Index 196: cedar city.
# ------------
# Retrieving Results for Index 197: ayaviri.
# ------------
# Retrieving Results for Index 198: labutta.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 199: khalkhal.
# ------------
# Retrieving Results for Index 200: natal.
# ------------
# Retrieving Results for Index 201: amahai.
# ------------
# Retrieving Results for Index 202: naze.
# ------------
# Retrieving Results for Index 203: ruteng.
# ------------
# Retrieving Results for Index 204: aksu.
# ------------
# Retrieving Results for Index 205: gornopravdinsk.
# ------------
# Retrieving Results for Index 206: fayaoue.
# ------------
# Retrieving Results for Index 207: pangody.
# ------------
# Retrieving Results for Index 208: wamba.
# ------------
# Retrieving Results for Index 209: vostok.
# ------------
# Retrieving Results for Index 210: matagami.
# ------------
# Retrieving Results for Index 211: pacific grove.
# ------------
# Retrieving Results for Index 212: tabuk.
# ------------
# Retrieving Results for Index 213: pedregulho.
# ------------
# Retrieving Results for Index 214: kirakira.
# ------------
# Retrieving Results for Index 215: sibu.
# ------------
# Retrieving Results for Index 216: esil.
# ------------
# Retrieving Results for Index 217: puerto escondido.
# ------------
# Retrieving Results for Index 218: los llanos de aridane.
# ------------
# Retrieving Results for Index 219: kattivakkam.
# ------------
# Retrieving Results for Index 220: iqaluit.
# ------------
# Retrieving Results for Index 221: pauini.
# ------------
# Retrieving Results for Index 222: yatou.
# ------------
# Retrieving Results for Index 223: pitimbu.
# ------------
# Retrieving Results for Index 224: ciudad bolivar.
# ------------
# Retrieving Results for Index 225: chapais.
# ------------
# Retrieving Results for Index 226: richards bay.
# ------------
# Retrieving Results for Index 227: sokoto.
# ------------
# Retrieving Results for Index 228: xining.
# ------------
# Retrieving Results for Index 229: batemans bay.
# ------------
# Retrieving Results for Index 230: esso.
# ------------
# Retrieving Results for Index 231: arman.
# ------------
# Retrieving Results for Index 232: nsanje.
# ------------
# Retrieving Results for Index 233: faya.
# ------------
# Retrieving Results for Index 234: asifabad.
# ------------
# Retrieving Results for Index 235: winona.
# ------------
# Retrieving Results for Index 236: kieta.
# ------------
# Retrieving Results for Index 237: kaitangata.
# ------------
# Retrieving Results for Index 238: lyantonde.
# ------------
# Retrieving Results for Index 239: zhicheng.
# ------------
# Retrieving Results for Index 240: sitka.
# ------------
# Retrieving Results for Index 241: saint-marc.
# ------------
# Retrieving Results for Index 242: amderma.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 243: sergeyevka.
# ------------
# Retrieving Results for Index 244: adrar.
# ------------
# Retrieving Results for Index 245: roseburg.
# ------------
# Retrieving Results for Index 246: eisiskes.
# ------------
# Retrieving Results for Index 247: sola.
# ------------
# Retrieving Results for Index 248: ponta delgada.
# ------------
# Retrieving Results for Index 249: masterton.
# ------------
# Retrieving Results for Index 250: te anau.
# ------------
# Retrieving Results for Index 251: vrises.
# ------------
# Retrieving Results for Index 252: vao.
# ------------
# Retrieving Results for Index 253: acapulco.
# ------------
# Retrieving Results for Index 254: nabire.
# ------------
# Retrieving Results for Index 255: geraldton.
# ------------
# Retrieving Results for Index 256: tucumcari.
# ------------
# Retrieving Results for Index 257: marawi.
# ------------
# Retrieving Results for Index 258: clyde river.
# ------------
# Retrieving Results for Index 259: grand river south east.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 260: jiazi.
# ------------
# Retrieving Results for Index 261: tiarei.
# ------------
# Retrieving Results for Index 262: san andres.
# ------------
# Retrieving Results for Index 263: hjelset.
# ------------
# Retrieving Results for Index 264: constitucion.
# ------------
# Retrieving Results for Index 265: betanzos.
# ------------
# Retrieving Results for Index 266: jiayuguan.
# ------------
# Retrieving Results for Index 267: witu.
# ------------
# Retrieving Results for Index 268: nemuro.
# ------------
# Retrieving Results for Index 269: longyearbyen.
# ------------
# Retrieving Results for Index 270: bubaque.
# ------------
# Retrieving Results for Index 271: honningsvag.
# ------------
# Retrieving Results for Index 272: teguldet.
# ------------
# Retrieving Results for Index 273: port moresby.
# ------------
# Retrieving Results for Index 274: zhanjiang.
# ------------
# Retrieving Results for Index 275: yagodnoye.
# ------------
# Retrieving Results for Index 276: wanning.
# ------------
# Retrieving Results for Index 277: georgetown.
# ------------
# Retrieving Results for Index 278: dickson.
# ------------
# Retrieving Results for Index 279: kautokeino.
# ------------
# Retrieving Results for Index 280: cordoba.
# ------------
# Retrieving Results for Index 281: flinders.
# ------------
# Retrieving Results for Index 282: terrace bay.
# ------------
# Retrieving Results for Index 283: corn island.
# ------------
# Retrieving Results for Index 284: kibondo.
# ------------
# Retrieving Results for Index 285: miri.
# ------------
# Retrieving Results for Index 286: mampong.
# ------------
# Retrieving Results for Index 287: kungurtug.
# ------------
# Retrieving Results for Index 288: danielskuil.
# ------------
# Retrieving Results for Index 289: boa vista.
# ------------
# Retrieving Results for Index 290: yar-sale.
# ------------
# Retrieving Results for Index 291: belyy yar.
# ------------
# Retrieving Results for Index 292: ponta do sol.
# ------------
# Retrieving Results for Index 293: waco.
# ------------
# Retrieving Results for Index 294: moorhead.
# ------------
# Retrieving Results for Index 295: ulladulla.
# ------------
# Retrieving Results for Index 296: ayagoz.
# ------------
# Retrieving Results for Index 297: eskilstuna.
# ------------
# Retrieving Results for Index 298: lorengau.
# ------------
# Retrieving Results for Index 299: jining.
# ------------
# Retrieving Results for Index 300: faanui.
# ------------
# Retrieving Results for Index 301: san felipe.
# ------------
# Retrieving Results for Index 302: khandyga.
# ------------
# Retrieving Results for Index 303: maniitsoq.
# ------------
# Retrieving Results for Index 304: namibe.
# ------------
# Retrieving Results for Index 305: utevka.
# ------------
# Retrieving Results for Index 306: lincoln.
# ------------
# Retrieving Results for Index 307: lavrentiya.
# ------------
# Retrieving Results for Index 308: zvishavane.
# ------------
# Retrieving Results for Index 309: gizo.
# ------------
# Retrieving Results for Index 310: quatre cocos.
# ------------
# Retrieving Results for Index 311: hohhot.
# ------------
# Retrieving Results for Index 312: belushya guba.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 313: stornoway.
# ------------
# Retrieving Results for Index 314: rungata.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 315: taltal.
# ------------
# Retrieving Results for Index 316: yayva.
# ------------
# Retrieving Results for Index 317: panino.
# ------------
# Retrieving Results for Index 318: maldonado.
# ------------
# Retrieving Results for Index 319: seondha.
# ------------
# Retrieving Results for Index 320: bengkulu.
# ------------
# Retrieving Results for Index 321: mangai.
# ------------
# Retrieving Results for Index 322: nadym.
# ------------
# Retrieving Results for Index 323: brae.
# ------------
# Retrieving Results for Index 324: keti bandar.
# ------------
# Retrieving Results for Index 325: chokurdakh.
# ------------
# Retrieving Results for Index 326: matamoros.
# ------------
# Retrieving Results for Index 327: road town.
# ------------
# Retrieving Results for Index 328: talara.
# ------------
# Retrieving Results for Index 329: kayes.
# ------------
# Retrieving Results for Index 330: nhulunbuy.
# ------------
# Retrieving Results for Index 331: fasa.
# ------------
# Retrieving Results for Index 332: margate.
# ------------
# Retrieving Results for Index 333: mehamn.
# ------------
# Retrieving Results for Index 334: monte alegre.
# ------------
# Retrieving Results for Index 335: nardaran.
# ------------
# Retrieving Results for Index 336: arcata.
# ------------
# Retrieving Results for Index 337: anadyr.
# ------------
# Retrieving Results for Index 338: dwarka.
# ------------
# Retrieving Results for Index 339: duminichi.
# ------------
# Retrieving Results for Index 340: pacifica.
# ------------
# Retrieving Results for Index 341: lac du bonnet.
# ------------
# Retrieving Results for Index 342: vila franca do campo.
# ------------
# Retrieving Results for Index 343: twin falls.
# ------------
# Retrieving Results for Index 344: ngunguru.
# ------------
# Retrieving Results for Index 345: samarai.
# ------------
# Retrieving Results for Index 346: vanimo.
# ------------
# Retrieving Results for Index 347: tilichiki.
# ------------
# Retrieving Results for Index 348: port-gentil.
# ------------
# Retrieving Results for Index 349: nelson bay.
# ------------
# Retrieving Results for Index 350: katesh.
# ------------
# Retrieving Results for Index 351: aripuana.
# ------------
# Retrieving Results for Index 352: aldan.
# ------------
# Retrieving Results for Index 353: castro.
# ------------
# Retrieving Results for Index 354: muros.
# ------------
# Retrieving Results for Index 355: beyneu.
# ------------
# Retrieving Results for Index 356: port elizabeth.
# ------------
# Retrieving Results for Index 357: manta.
# ------------
# Retrieving Results for Index 358: marsa matruh.
# ------------
# Retrieving Results for Index 359: babanusah.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 360: grand centre.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 361: wewak.
# ------------
# Retrieving Results for Index 362: tuatapere.
# ------------
# Retrieving Results for Index 363: andenes.
# ------------
# Retrieving Results for Index 364: igbo ora.
# ------------
# Retrieving Results for Index 365: panguna.
# ------------
# Retrieving Results for Index 366: kyabe.
# ------------
# Retrieving Results for Index 367: sidmouth.
# ------------
# Retrieving Results for Index 368: jhargram.
# ------------
# Retrieving Results for Index 369: norsup.
# ------------
# Retrieving Results for Index 370: tahta.
# ------------
# Retrieving Results for Index 371: narsaq.
# ------------
# Retrieving Results for Index 372: najran.
# ------------
# Retrieving Results for Index 373: aguadilla.
# ------------
# Retrieving Results for Index 374: tazovskiy.
# ------------
# Retrieving Results for Index 375: nuuk.
# ------------
# Retrieving Results for Index 376: baglung.
# ------------
# Retrieving Results for Index 377: arshan.
# ------------
# Retrieving Results for Index 378: sangar.
# ------------
# Retrieving Results for Index 379: pisco.
# ------------
# Retrieving Results for Index 380: ilanskiy.
# ------------
# Retrieving Results for Index 381: kavieng.
# ------------
# Retrieving Results for Index 382: ewa beach.
# ------------
# Retrieving Results for Index 383: gorontalo.
# ------------
# Retrieving Results for Index 384: toribio.
# ------------
# Retrieving Results for Index 385: pangoa.
# ------------
# Retrieving Results for Index 386: nouakchott.
# ------------
# Retrieving Results for Index 387: fairbanks.
# ------------
# Retrieving Results for Index 388: mont-de-marsan.
# ------------
# Retrieving Results for Index 389: sidney.
# ------------
# Retrieving Results for Index 390: pathein.
# ------------
# Retrieving Results for Index 391: pandan.
# ------------
# Retrieving Results for Index 392: zhigansk.
# ------------
# Retrieving Results for Index 393: nanortalik.
# ------------
# Retrieving Results for Index 394: saint-pierre.
# ------------
# Retrieving Results for Index 395: suzun.
# ------------
# Retrieving Results for Index 396: ancud.
# ------------
# Retrieving Results for Index 397: changde.
# ------------
# Retrieving Results for Index 398: samusu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 399: norwich.
# ------------
# Retrieving Results for Index 400: bilibino.
# ------------
# Retrieving Results for Index 401: berdigestyakh.
# ------------
# Retrieving Results for Index 402: emilio carranza.
# ------------
# Retrieving Results for Index 403: guadalupe y calvo.
# ------------
# Retrieving Results for Index 404: inderborskiy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 405: aswan.
# ------------
# Retrieving Results for Index 406: komsomolskiy.
# ------------
# Retrieving Results for Index 407: sile.
# ------------
# Retrieving Results for Index 408: husavik.
# ------------
# Retrieving Results for Index 409: marcona.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 410: gulshat.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 411: okmulgee.
# ------------
# Retrieving Results for Index 412: yuxia.
# ------------
# Retrieving Results for Index 413: sinaloa.
# ------------
# Retrieving Results for Index 414: tumannyy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 415: palizada.
# ------------
# Retrieving Results for Index 416: ngukurr.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 417: lazdijai.
# ------------
# Retrieving Results for Index 418: mayor pablo lagerenza.
# ------------
# Retrieving Results for Index 419: talnakh.
# ------------
# Retrieving Results for Index 420: manbij.
# ------------
# Retrieving Results for Index 421: ambovombe.
# ------------
# Retrieving Results for Index 422: pyinmana.
# ------------
# Retrieving Results for Index 423: aflu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 424: chingirlau.
# ------------
# Retrieving Results for Index 425: nauen.
# ------------
# Retrieving Results for Index 426: port macquarie.
# ------------
# Retrieving Results for Index 427: beloha.
# ------------
# Retrieving Results for Index 428: ucluelet.
# ------------
# Retrieving Results for Index 429: praia da vitoria.
# ------------
# Retrieving Results for Index 430: binzhou.
# ------------
# Retrieving Results for Index 431: benguela.
# ------------
# Retrieving Results for Index 432: saint-joseph.
# ------------
# Retrieving Results for Index 433: along.
# ------------
# Retrieving Results for Index 434: hay river.
# ------------
# Retrieving Results for Index 435: marsh harbour.
# ------------
# Retrieving Results for Index 436: beringovskiy.
# ------------
# Retrieving Results for Index 437: carrickfergus.
# ------------
# Retrieving Results for Index 438: dromolaxia.
# ------------
# Retrieving Results for Index 439: college.
# ------------
# Retrieving Results for Index 440: oktyabrskiy.
# ------------
# Retrieving Results for Index 441: viedma.
# ------------
# Retrieving Results for Index 442: karratha.
# ------------
# Retrieving Results for Index 443: venado tuerto.
# ------------
# Retrieving Results for Index 444: derazhnya.
# ------------
# Retrieving Results for Index 445: muroto.
# ------------
# Retrieving Results for Index 446: hebi.
# ------------
# Retrieving Results for Index 447: taldan.
# ------------
# Retrieving Results for Index 448: kuito.
# ------------
# Retrieving Results for Index 449: ilam.
# ------------
# Retrieving Results for Index 450: half moon bay.
# ------------
# Retrieving Results for Index 451: xuanzhou.
# ------------
# Retrieving Results for Index 452: mae ramat.
# ------------
# Retrieving Results for Index 453: rio gallegos.
# ------------
# Retrieving Results for Index 454: carauari.
# ------------
# Retrieving Results for Index 455: sentyabrskiy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 456: meulaboh.
# ------------
# Retrieving Results for Index 457: champerico.
# ------------
# Retrieving Results for Index 458: pathalgaon.
# ------------
# Retrieving Results for Index 459: waddan.
# ------------
# Retrieving Results for Index 460: banda aceh.
# ------------
# Retrieving Results for Index 461: beira.
# ------------
# Retrieving Results for Index 462: cherskiy.
# ------------
# Retrieving Results for Index 463: ranong.
# ------------
# Retrieving Results for Index 464: salina.
# ------------
# Retrieving Results for Index 465: bolungarvik.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 466: bethel.
# ------------
# Retrieving Results for Index 467: ixtapa.
# ------------
# Retrieving Results for Index 468: palu.
# ------------
# Retrieving Results for Index 469: sterling.
# ------------
# Retrieving Results for Index 470: lolua.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 471: maningrida.
# ------------
# Retrieving Results for Index 472: wladyslawowo.
# ------------
# Retrieving Results for Index 473: lima.
# ------------
# Retrieving Results for Index 474: beeskow.
# ------------
# Retrieving Results for Index 475: gambela.
# ------------
# Retrieving Results for Index 476: sidi ali.
# ------------
# Retrieving Results for Index 477: verkhnevilyuysk.
# ------------
# Retrieving Results for Index 478: machico.
# ------------
# Retrieving Results for Index 479: markivka.
# ------------
# Retrieving Results for Index 480: shu.
# ------------
# Retrieving Results for Index 481: kusti.
# ------------
# Retrieving Results for Index 482: hirara.
# ------------
# Retrieving Results for Index 483: chinna salem.
# ------------
# Retrieving Results for Index 484: pittsburg.
# ------------
# Retrieving Results for Index 485: raga.
# ------------
# Retrieving Results for Index 486: martapura.
# ------------
# Retrieving Results for Index 487: tukrah.
# ------------
# Retrieving Results for Index 488: saucillo.
# ------------
# Retrieving Results for Index 489: santa cruz.
# ------------
# Retrieving Results for Index 490: haines junction.
# ------------
# Retrieving Results for Index 491: mendoza.
# ------------
# Retrieving Results for Index 492: rudnya.
# ------------
# Retrieving Results for Index 493: ostrovnoy.
# ------------
# Retrieving Results for Index 494: north platte.
# ------------
# Retrieving Results for Index 495: kondopoga.
# ------------
# Retrieving Results for Index 496: piacabucu.
# ------------
# Retrieving Results for Index 497: lagos.
# ------------
# Retrieving Results for Index 498: port hedland.
# ------------
# Retrieving Results for Index 499: alofi.
# ------------
# Retrieving Results for Index 500: abu samrah.
# ------------
# Retrieving Results for Index 501: grand gaube.
# ------------
# Retrieving Results for Index 502: sudak.
# ------------
# Retrieving Results for Index 503: taunggyi.
# ------------
# Retrieving Results for Index 504: jumla.
# ------------
# Retrieving Results for Index 505: warqla.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 506: morondava.
# ------------
# Retrieving Results for Index 507: padang.
# ------------
# Retrieving Results for Index 508: riyadh.
# ------------
# Retrieving Results for Index 509: shingu.
# ------------
# Retrieving Results for Index 510: kulhudhuffushi.
# ------------
# Retrieving Results for Index 511: marienburg.
# ------------
# Retrieving Results for Index 512: baykit.
# ------------
# Retrieving Results for Index 513: kudahuvadhoo.
# ------------
# Retrieving Results for Index 514: egvekinot.

# %%
cities_df.index.names = ["city_ID"]

cities_df["date"] = pd.to_datetime(cities_df['date'],unit='s')

# %%
cities_df['date'] = cities_df['date'].dt.strftime('%m/%d/%Y')

cities_df

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.to_csv('/Users/jenniferramsey/hw/Python_API/output_data/cities.csv', index=True)

# %%
cities_df.head()

#cities_df['wind_speed'].min(), cities_df['wind_speed'].max()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
date = cities_df['date'].unique()
print(date[0])

x_axis = cities_df['latitude']
y_axis = cities_df['max_temp']

plt.scatter(x_axis, y_axis, facecolors="red", edgecolors="black", alpha=1.0)
plt.xlim(-60, 90)
plt.ylim((cities_df['max_temp'].min() - 10), (cities_df['max_temp'].max() + 10))
plt.title('Latitude vs Max Temperature (F) on ' + str(date[0]))
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

plt.savefig('/Users/jenniferramsey/hw/Python_API/output_data/latitudeVtemp.png')

plt.show()
##Measuring the relationship between Latitude (Distance from the equator) and the Max Temp for the region.
##The closer the city is to the equator (lat = 0), the higher the temperature.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_axis = cities_df['latitude']
y_axis = cities_df['humidity']

plt.scatter(x_axis, y_axis, facecolors="red", edgecolors="black", alpha=1.0)
plt.xlim(-60, 90)
plt.ylim((cities_df['humidity'].min() - 10), (cities_df['humidity'].max() + 10))
plt.title('Latitude vs Humidity % on ' + str(date[0]))
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.savefig('/Users/jenniferramsey/hw/Python_API/output_data/latitudeVhumidity.png')

plt.show()

##measuring the relationship between Latitude and Humidity.
##there does not appear to be any strong relationship between latitude and humidity.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_axis = cities_df['latitude']
y_axis = cities_df['cloudiness']

plt.scatter(x_axis, y_axis, facecolors="red", edgecolors="black", alpha=1.0)
plt.xlim(-60, 90)
plt.ylim((cities_df['cloudiness'].min() - 10), (cities_df['cloudiness'].max() + 10))
plt.title('Latitude vs Cloudiness %  on ' + str(date[0]))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')

plt.savefig('/Users/jenniferramsey/hw/Python_API/output_data/latitudeVcloudiness.png')

plt.show()

#measuring the relationship between latitude and cloudiness.
##there does not appear to be a strong relationship between latitude and cloudiness

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_axis = cities_df['latitude']
y_axis = cities_df['wind_speed']

plt.scatter(x_axis, y_axis, facecolors="red", edgecolors="black", alpha=1.0)
plt.xlim(-60, 90)
plt.ylim((cities_df['wind_speed'].min() - 10), (cities_df['wind_speed'].max() + 10))
plt.title('Latitude vs Wind Speed MPH  on ' + str(date[0]))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed MPH')

plt.savefig('/Users/jenniferramsey/hw/Python_API/output_data/latitudeVwind.png')

plt.show()

#measuring the relationship between latitude and wind speed.
##there does not appear to be a significant relationship between latitude and wind speed,
#but the data may support stronger winds closer to the poles

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = cities_df[cities_df.latitude >= 0]
#northern_hemisphere

southern_hemisphere = cities_df[cities_df.latitude < 0]
#southern_hemisphere

#southern_hemisphere['latitude'].max(), northern_hemisphere['latitude'].min()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = northern_hemisphere['latitude']
y_axis = northern_hemisphere['max_temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis, facecolors="red", edgecolors="black", alpha=1.0)
plt.xlim(-10, 90)
plt.ylim((northern_hemisphere['max_temp'].min() - 10), (northern_hemisphere['max_temp'].max() + 10))
plt.plot(x_axis,regress_values,"b-")
plt.annotate(line_eq,(6,10),fontsize=15,color="blue")
plt.title('Northern Latitude vs Max Temperature (F) on ' + str(date[0]))
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

plt.savefig('/Users/jenniferramsey/hw/Python_API/output_data/NORTHlatitudeVtemp.png')

plt.show()

##measuring the relationship between latitude and temperature in the NORTHERN hemisphere.
##There is a relationship of decrease of temperature as latitude increases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = southern_hemisphere['latitude']
y_axis = southern_hemisphere['max_temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis, facecolors="blue", edgecolors="black", alpha=1.0)
plt.xlim(-60, 10)
plt.ylim((southern_hemisphere['max_temp'].min() - 10), (southern_hemisphere['max_temp'].max() + 10))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-50,90),fontsize=15,color="red")
plt.title('Southern Latitude vs Max Temperature (F) on ' + str(date[0]))
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

plt.savefig('/Users/jenniferramsey/hw/Python_API/output_data/SOUTHlatitudeVtemp.png')

plt.show()

##measuring the relationship between latitude and temperature in the SOUTHERN hemisphere.
##There is a relationship of decrease of temperature as latitude decreases,
##though not as sharply as in the north.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = northern_hemisphere['latitude']
y_axis = northern_hemisphere['humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis, facecolors="red", edgecolors="black", alpha=1.0)
plt.xlim(-10, 90)
plt.ylim((northern_hemisphere['humidity'].min() - 10), (northern_hemisphere['humidity'].max() + 10))
plt.plot(x_axis,regress_values,"b-")
plt.annotate(line_eq,(40,10),fontsize=15,color="blue")
plt.title('Northern Latitude vs Humidity (%) on ' + str(date[0]))
plt.xlabel('Latitude')
plt.ylabel('Humididty (%)')

plt.savefig('/Users/jenniferramsey/hw/Python_API/output_data/NORTHlatitudeVhumidity.png')

plt.show()
##measuring the relationship between Latitude and Humidity in the NORTHERN hemisphere.
##regression indicates that there is some evidence that as latitude rises, Humdity rises slightly.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = southern_hemisphere['latitude']
y_axis = southern_hemisphere['humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis, facecolors="blue", edgecolors="black", alpha=1.0)
plt.xlim(-60, 10)
plt.ylim((southern_hemisphere['humidity'].min() - 10), (southern_hemisphere['humidity'].max() + 10))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-50,15),fontsize=15,color="red")
plt.title('Southern Latitude vs Humidity (%) on ' + str(date[0]))
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

plt.savefig('/Users/jenniferramsey/hw/Python_API/output_data/SOUTHlatitudeVhumidity.png')

plt.show()

##measuring the relationship between Latitude and Humidity in the SOUTHERN hemisphere.
##regression indicates that there is some evidence that as latitude rises, Humdity rises slightly.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = northern_hemisphere['latitude']
y_axis = northern_hemisphere['cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis, facecolors="red", edgecolors="black", alpha=1.0)
plt.xlim(-10, 90)
plt.ylim((northern_hemisphere['cloudiness'].min() - 10), (northern_hemisphere['cloudiness'].max() + 10))
plt.plot(x_axis,regress_values,"b-")
plt.annotate(line_eq,(75,10),fontsize=15,color="blue")
plt.title('Northern Latitude vs Cloudiness (%) on ' + str(date[0]))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

plt.savefig('/Users/jenniferramsey/hw/Python_API/output_data/NORTHlatitudeVcloudiness.png')

plt.show()

##measuring the relationship between Latitude and Cloudiness in the NORTHERN hemisphere.
##regression indicates that there is some evidence that as latitude rises, cloudiness rises slightly.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = southern_hemisphere['latitude']
y_axis = southern_hemisphere['cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis, facecolors="blue", edgecolors="black", alpha=1.0)
plt.xlim(-60, 10)
plt.ylim((southern_hemisphere['cloudiness'].min() - 10), (southern_hemisphere['cloudiness'].max() + 10))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-50,15),fontsize=15,color="red")
plt.title('Southern Latitude vs Cloudiness (%) on ' + str(date[0]))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

plt.savefig('/Users/jenniferramsey/hw/Python_API/output_data/SOUTHlatitudeVcloudiness.png')

plt.show()

##measuring the relationship between Latitude and Cloudiness in the SOUTHERN hemisphere.
##regression indicates that there is some evidence that as latitude rises, cloudiness rises slightly.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = northern_hemisphere['latitude']
y_axis = northern_hemisphere['wind_speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis, facecolors="red", edgecolors="black", alpha=1.0)
plt.xlim(-10, 90)
plt.ylim((northern_hemisphere['wind_speed'].min() - 10), (northern_hemisphere['wind_speed'].max() + 10))
plt.plot(x_axis,regress_values,"b-")
plt.annotate(line_eq,(0,40),fontsize=15,color="blue")
plt.title('Northern Latitude vs Wind Speed (MPH) on ' + str(date[0]))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')

plt.savefig('/Users/jenniferramsey/hw/Python_API/output_data/NORTHlatitudeVwind.png')

plt.show()

##measuring the relationship between Latitude and Windspeer in the NORTHERN hemisphere.
##regression indicates that there is some evidence that as latitude rises, wind speed rises somewhat.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = southern_hemisphere['latitude']
y_axis = southern_hemisphere['wind_speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis, facecolors="blue", edgecolors="black", alpha=1.0)
plt.xlim(-60, 10)
plt.ylim((southern_hemisphere['wind_speed'].min() - 10), (southern_hemisphere['wind_speed'].max() + 10))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-50,30),fontsize=15,color="red")
plt.title('Southern Latitude vs Wind Speed (MPH) on ' + str(date[0]))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')

plt.savefig('/Users/jenniferramsey/hw/Python_API/output_data/SOUTHlatitudeVwind.png')


plt.show()

##measuring the relationship between Latitude and Windspeer in the SOUTHERN hemisphere.
##regression indicates that there is some evidence that as latitude rises, wind speed decreases the tiniest bit.
