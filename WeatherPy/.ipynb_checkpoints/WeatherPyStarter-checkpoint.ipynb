# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.
#
#
# *In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator.
#
# *To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy),
#
# *the [OpenWeatherMap API](https://openweathermap.org/api),
#
# *and a little common sense to create a representative model of weather across world cities.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 580

# %%
cities_df = pd.DataFrame(cities, columns = ['city'])
cities_df
# Out:
#             city
# 0          vaini
# 1    new norfolk
# 2         dikson
# 3     chokurdakh
# 4       katsuura
# ..           ...
# 575      le port
# 576       yaring
# 577      manyana
# 578        gimli
# 579    massakory
#
# [580 rows x 1 columns]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

weather_query_url = f"{base_url}&APPID={weather_api_key}"


print(weather_query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?&APPID=8946465e1a8d147457256e3299779a5b

# %%
# Get weather data
# use iterrows to iterate through pandas dataframe
temperature = []
index = []

cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []


Error_count = 0
for index, row in cities_df.iterrows():

    # get city name from df
    city_name = row['city']
    
    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {city_name}.")
    #final_weather_query_url = weather_query_url + "&q="+ city_name +"&units="+units
    #print(final_weather_query_url)
    weather_json = requests.get(weather_query_url + "&q="+ city_name +"&units="+units).json()
    #pprint(weather_json)
    
    ##extract results
    try:
        #Cloudiness
        cloudiness = weather_json["clouds"]["all"]
        cities_df.loc[index, 'cloudiness'] = cloudiness
        #Country
        country = weather_json["sys"]["country"]
        cities_df.loc[index, 'country'] = country
        #date
        date = weather_json["dt"]
        cities_df.loc[index, 'date'] = date
        #humidity
        humidity = weather_json["main"]["humidity"]
        cities_df.loc[index, 'humidity'] = humidity
        #latitude
        latitude = weather_json["coord"]["lat"]
        cities_df.loc[index, 'latitude'] = latitude
        #longitude
        longitude = weather_json["coord"]["lon"]
        cities_df.loc[index, 'longitude'] = longitude
        #Max Temp
        max_temp = weather_json["main"]["temp_max"]
        cities_df.loc[index, 'max_temp'] = max_temp
        #wind_speed
        wind_speed = weather_json["wind"]["speed"]
        cities_df.loc[index, 'wind_speed'] = wind_speed
        
        
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        Error_count = Error_count +1 
    print("------------")
# Out:
# Retrieving Results for Index 0: vaini.
# ------------
# Retrieving Results for Index 1: new norfolk.
# ------------
# Retrieving Results for Index 2: dikson.
# ------------
# Retrieving Results for Index 3: chokurdakh.
# ------------
# Retrieving Results for Index 4: katsuura.
# ------------
# Retrieving Results for Index 5: yellowknife.
# ------------
# Retrieving Results for Index 6: kruisfontein.
# ------------
# Retrieving Results for Index 7: luderitz.
# ------------
# Retrieving Results for Index 8: nikolskoye.
# ------------
# Retrieving Results for Index 9: baherden.
# ------------
# Retrieving Results for Index 10: taoudenni.
# ------------
# Retrieving Results for Index 11: lebowakgomo.
# ------------
# Retrieving Results for Index 12: khani.
# ------------
# Retrieving Results for Index 13: college.
# ------------
# Retrieving Results for Index 14: thompson.
# ------------
# Retrieving Results for Index 15: cayenne.
# ------------
# Retrieving Results for Index 16: shenxian.
# ------------
# Retrieving Results for Index 17: klaksvik.
# ------------
# Retrieving Results for Index 18: albany.
# ------------
# Retrieving Results for Index 19: barrow.
# ------------
# Retrieving Results for Index 20: norman wells.
# ------------
# Retrieving Results for Index 21: hilo.
# ------------
# Retrieving Results for Index 22: saskylakh.
# ------------
# Retrieving Results for Index 23: faanui.
# ------------
# Retrieving Results for Index 24: tessalit.
# ------------
# Retrieving Results for Index 25: punta arenas.
# ------------
# Retrieving Results for Index 26: atuona.
# ------------
# Retrieving Results for Index 27: fairbanks.
# ------------
# Retrieving Results for Index 28: charters towers.
# ------------
# Retrieving Results for Index 29: meulaboh.
# ------------
# Retrieving Results for Index 30: ribeira grande.
# ------------
# Retrieving Results for Index 31: porto walter.
# ------------
# Retrieving Results for Index 32: tasiilaq.
# ------------
# Retrieving Results for Index 33: tari.
# ------------
# Retrieving Results for Index 34: labytnangi.
# ------------
# Retrieving Results for Index 35: oktyabrskiy.
# ------------
# Retrieving Results for Index 36: sabinas hidalgo.
# ------------
# Retrieving Results for Index 37: attawapiskat.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 38: taolanaro.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 39: esna.
# ------------
# Retrieving Results for Index 40: qaanaaq.
# ------------
# Retrieving Results for Index 41: tumannyy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 42: ushuaia.
# ------------
# Retrieving Results for Index 43: torbay.
# ------------
# Retrieving Results for Index 44: provideniya.
# ------------
# Retrieving Results for Index 45: constitucion.
# ------------
# Retrieving Results for Index 46: cidreira.
# ------------
# Retrieving Results for Index 47: busselton.
# ------------
# Retrieving Results for Index 48: karauzyak.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 49: bluff.
# ------------
# Retrieving Results for Index 50: atar.
# ------------
# Retrieving Results for Index 51: mar del plata.
# ------------
# Retrieving Results for Index 52: bandarbeyla.
# ------------
# Retrieving Results for Index 53: la ronge.
# ------------
# Retrieving Results for Index 54: georgetown.
# ------------
# Retrieving Results for Index 55: severo-kurilsk.
# ------------
# Retrieving Results for Index 56: key biscayne.
# ------------
# Retrieving Results for Index 57: koygorodok.
# ------------
# Retrieving Results for Index 58: akyab.
# ------------
# Retrieving Results for Index 59: virginia beach.
# ------------
# Retrieving Results for Index 60: ereymentau.
# ------------
# Retrieving Results for Index 61: geraldton.
# ------------
# Retrieving Results for Index 62: rikitea.
# ------------
# Retrieving Results for Index 63: susanville.
# ------------
# Retrieving Results for Index 64: barentsburg.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 65: sao filipe.
# ------------
# Retrieving Results for Index 66: arona.
# ------------
# Retrieving Results for Index 67: hithadhoo.
# ------------
# Retrieving Results for Index 68: mataura.
# ------------
# Retrieving Results for Index 69: kahului.
# ------------
# Retrieving Results for Index 70: ponta do sol.
# ------------
# Retrieving Results for Index 71: mahdasht.
# ------------
# Retrieving Results for Index 72: longyearbyen.
# ------------
# Retrieving Results for Index 73: louisbourg.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 74: puerto ayora.
# ------------
# Retrieving Results for Index 75: gasa.
# ------------
# Retrieving Results for Index 76: perbaungan.
# ------------
# Retrieving Results for Index 77: port hardy.
# ------------
# Retrieving Results for Index 78: daru.
# ------------
# Retrieving Results for Index 79: cape town.
# ------------
# Retrieving Results for Index 80: saldanha.
# ------------
# Retrieving Results for Index 81: victor harbor.
# ------------
# Retrieving Results for Index 82: saint-philippe.
# ------------
# Retrieving Results for Index 83: beloha.
# ------------
# Retrieving Results for Index 84: nanortalik.
# ------------
# Retrieving Results for Index 85: livny.
# ------------
# Retrieving Results for Index 86: chiredzi.
# ------------
# Retrieving Results for Index 87: salt.
# ------------
# Retrieving Results for Index 88: bumba.
# ------------
# Retrieving Results for Index 89: roma.
# ------------
# Retrieving Results for Index 90: tomatlan.
# ------------
# Retrieving Results for Index 91: bambous virieux.
# ------------
# Retrieving Results for Index 92: tuatapere.
# ------------
# Retrieving Results for Index 93: port alfred.
# ------------
# Retrieving Results for Index 94: jitia.
# ------------
# Retrieving Results for Index 95: pangoa.
# ------------
# Retrieving Results for Index 96: okha.
# ------------
# Retrieving Results for Index 97: khatanga.
# ------------
# Retrieving Results for Index 98: kavaratti.
# ------------
# Retrieving Results for Index 99: kaitangata.
# ------------
# Retrieving Results for Index 100: suruc.
# ------------
# Retrieving Results for Index 101: saint-paul.
# ------------
# Retrieving Results for Index 102: san ramon de la nueva oran.
# ------------
# Retrieving Results for Index 103: talaya.
# ------------
# Retrieving Results for Index 104: cherepanovo.
# ------------
# Retrieving Results for Index 105: clyde river.
# ------------
# Retrieving Results for Index 106: lompoc.
# ------------
# Retrieving Results for Index 107: waipawa.
# ------------
# Retrieving Results for Index 108: kapaa.
# ------------
# Retrieving Results for Index 109: evanston.
# ------------
# Retrieving Results for Index 110: tuensang.
# ------------
# Retrieving Results for Index 111: kodiak.
# ------------
# Retrieving Results for Index 112: illoqqortoormiut.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 113: upernavik.
# ------------
# Retrieving Results for Index 114: mount isa.
# ------------
# Retrieving Results for Index 115: kuliyapitiya.
# ------------
# Retrieving Results for Index 116: victoria.
# ------------
# Retrieving Results for Index 117: belushya guba.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 118: antofagasta.
# ------------
# Retrieving Results for Index 119: tambura.
# ------------
# Retrieving Results for Index 120: bredasdorp.
# ------------
# Retrieving Results for Index 121: ilulissat.
# ------------
# Retrieving Results for Index 122: guamuchil.
# ------------
# Retrieving Results for Index 123: myanaung.
# ------------
# Retrieving Results for Index 124: kidal.
# ------------
# Retrieving Results for Index 125: waingapu.
# ------------
# Retrieving Results for Index 126: aripuana.
# ------------
# Retrieving Results for Index 127: castro.
# ------------
# Retrieving Results for Index 128: dire dawa.
# ------------
# Retrieving Results for Index 129: lotofaga.
# ------------
# Retrieving Results for Index 130: viedma.
# ------------
# Retrieving Results for Index 131: mundo nuevo.
# ------------
# Retrieving Results for Index 132: port hedland.
# ------------
# Retrieving Results for Index 133: port-de-paix.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 134: storforshei.
# ------------
# Retrieving Results for Index 135: vardo.
# ------------
# Retrieving Results for Index 136: souillac.
# ------------
# Retrieving Results for Index 137: jamestown.
# ------------
# Retrieving Results for Index 138: bababe.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 139: sitangkai.
# ------------
# Retrieving Results for Index 140: carballo.
# ------------
# Retrieving Results for Index 141: palabuhanratu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 142: mount gambier.
# ------------
# Retrieving Results for Index 143: batouri.
# ------------
# Retrieving Results for Index 144: miramar.
# ------------
# Retrieving Results for Index 145: henties bay.
# ------------
# Retrieving Results for Index 146: jalu.
# ------------
# Retrieving Results for Index 147: lebu.
# ------------
# Retrieving Results for Index 148: karratha.
# ------------
# Retrieving Results for Index 149: lyngseidet.
# ------------
# Retrieving Results for Index 150: kegayli.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 151: duayaw nkwanta.
# ------------
# Retrieving Results for Index 152: vanavara.
# ------------
# Retrieving Results for Index 153: san cristobal.
# ------------
# Retrieving Results for Index 154: sao gabriel.
# ------------
# Retrieving Results for Index 155: khonuu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 156: lagoa.
# ------------
# Retrieving Results for Index 157: chimbote.
# ------------
# Retrieving Results for Index 158: hobart.
# ------------
# Retrieving Results for Index 159: kamenskoye.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 160: heilbron.
# ------------
# Retrieving Results for Index 161: avarua.
# ------------
# Retrieving Results for Index 162: qasigiannguit.
# ------------
# Retrieving Results for Index 163: tateyama.
# ------------
# Retrieving Results for Index 164: west bay.
# ------------
# Retrieving Results for Index 165: kavarna.
# ------------
# Retrieving Results for Index 166: moron.
# ------------
# Retrieving Results for Index 167: sakakah.
# ------------
# Retrieving Results for Index 168: ulladulla.
# ------------
# Retrieving Results for Index 169: gurskoye.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 170: dolbeau.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 171: de aar.
# ------------
# Retrieving Results for Index 172: namatanai.
# ------------
# Retrieving Results for Index 173: nome.
# ------------
# Retrieving Results for Index 174: fortuna.
# ------------
# Retrieving Results for Index 175: aylesbury.
# ------------
# Retrieving Results for Index 176: aklavik.
# ------------
# Retrieving Results for Index 177: saleaula.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 178: bethel.
# ------------
# Retrieving Results for Index 179: luangwa.
# ------------
# Retrieving Results for Index 180: kualakapuas.
# ------------
# Retrieving Results for Index 181: east london.
# ------------
# Retrieving Results for Index 182: chuy.
# ------------
# Retrieving Results for Index 183: kalomo.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 184: hermanus.
# ------------
# Retrieving Results for Index 185: huarmey.
# ------------
# Retrieving Results for Index 186: fare.
# ------------
# Retrieving Results for Index 187: samusu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 188: el prat de llobregat.
# ------------
# Retrieving Results for Index 189: saint george.
# ------------
# Retrieving Results for Index 190: ust-kamchatsk.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 191: idrinskoye.
# ------------
# Retrieving Results for Index 192: aswan.
# ------------
# Retrieving Results for Index 193: pangnirtung.
# ------------
# Retrieving Results for Index 194: parry sound.
# ------------
# Retrieving Results for Index 195: pisco.
# ------------
# Retrieving Results for Index 196: port elizabeth.
# ------------
# Retrieving Results for Index 197: solikamsk.
# ------------
# Retrieving Results for Index 198: vicosa.
# ------------
# Retrieving Results for Index 199: khed brahma.
# ------------
# Retrieving Results for Index 200: arrecife.
# ------------
# Retrieving Results for Index 201: jacqueville.
# ------------
# Retrieving Results for Index 202: dhidhdhoo.
# ------------
# Retrieving Results for Index 203: gold coast.
# ------------
# Retrieving Results for Index 204: namibe.
# ------------
# Retrieving Results for Index 205: airai.
# ------------
# Retrieving Results for Index 206: tuktoyaktuk.
# ------------
# Retrieving Results for Index 207: yulara.
# ------------
# Retrieving Results for Index 208: chagda.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 209: tabiauea.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 210: pemangkat.
# ------------
# Retrieving Results for Index 211: abha.
# ------------
# Retrieving Results for Index 212: bemidji.
# ------------
# Retrieving Results for Index 213: ponazyrevo.
# ------------
# Retrieving Results for Index 214: lazaro cardenas.
# ------------
# Retrieving Results for Index 215: skegness.
# ------------
# Retrieving Results for Index 216: dingle.
# ------------
# Retrieving Results for Index 217: camocim.
# ------------
# Retrieving Results for Index 218: sechura.
# ------------
# Retrieving Results for Index 219: aquiraz.
# ------------
# Retrieving Results for Index 220: tiksi.
# ------------
# Retrieving Results for Index 221: nouakchott.
# ------------
# Retrieving Results for Index 222: daura.
# ------------
# Retrieving Results for Index 223: kismayo.
# ------------
# Retrieving Results for Index 224: san patricio.
# ------------
# Retrieving Results for Index 225: san matias.
# ------------
# Retrieving Results for Index 226: malazgirt.
# ------------
# Retrieving Results for Index 227: port blair.
# ------------
# Retrieving Results for Index 228: sinegorye.
# ------------
# Retrieving Results for Index 229: laguna.
# ------------
# Retrieving Results for Index 230: cherskiy.
# ------------
# Retrieving Results for Index 231: tura.
# ------------
# Retrieving Results for Index 232: liusha.
# ------------
# Retrieving Results for Index 233: trzic.
# ------------
# Retrieving Results for Index 234: rawson.
# ------------
# Retrieving Results for Index 235: ban nahin.
# ------------
# Retrieving Results for Index 236: uusikaupunki.
# ------------
# Retrieving Results for Index 237: kloulklubed.
# ------------
# Retrieving Results for Index 238: cabo san lucas.
# ------------
# Retrieving Results for Index 239: jiazi.
# ------------
# Retrieving Results for Index 240: calvinia.
# ------------
# Retrieving Results for Index 241: altay.
# ------------
# Retrieving Results for Index 242: delmas.
# ------------
# Retrieving Results for Index 243: ucluelet.
# ------------
# Retrieving Results for Index 244: nizhneyansk.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 245: lesnoy.
# ------------
# Retrieving Results for Index 246: walvis bay.
# ------------
# Retrieving Results for Index 247: kupang.
# ------------
# Retrieving Results for Index 248: grand river south east.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 249: butaritari.
# ------------
# Retrieving Results for Index 250: fayaoue.
# ------------
# Retrieving Results for Index 251: rio branco.
# ------------
# Retrieving Results for Index 252: nara.
# ------------
# Retrieving Results for Index 253: babanusah.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 254: chara.
# ------------
# Retrieving Results for Index 255: karpathos.
# ------------
# Retrieving Results for Index 256: iskateley.
# ------------
# Retrieving Results for Index 257: bandar-e torkaman.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 258: narsaq.
# ------------
# Retrieving Results for Index 259: mollendo.
# ------------
# Retrieving Results for Index 260: maldonado.
# ------------
# Retrieving Results for Index 261: kabalo.
# ------------
# Retrieving Results for Index 262: lorengau.
# ------------
# Retrieving Results for Index 263: dunedin.
# ------------
# Retrieving Results for Index 264: knysna.
# ------------
# Retrieving Results for Index 265: san gabriel.
# ------------
# Retrieving Results for Index 266: kolomak.
# ------------
# Retrieving Results for Index 267: pevek.
# ------------
# Retrieving Results for Index 268: boa vista.
# ------------
# Retrieving Results for Index 269: pitimbu.
# ------------
# Retrieving Results for Index 270: znamenskoye.
# ------------
# Retrieving Results for Index 271: erenhot.
# ------------
# Retrieving Results for Index 272: vytegra.
# ------------
# Retrieving Results for Index 273: vostok.
# ------------
# Retrieving Results for Index 274: austin.
# ------------
# Retrieving Results for Index 275: mahoba.
# ------------
# Retrieving Results for Index 276: monte siao.
# ------------
# Retrieving Results for Index 277: tabou.
# ------------
# Retrieving Results for Index 278: pacific grove.
# ------------
# Retrieving Results for Index 279: coquimbo.
# ------------
# Retrieving Results for Index 280: dodge city.
# ------------
# Retrieving Results for Index 281: stoyba.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 282: bonavista.
# ------------
# Retrieving Results for Index 283: talnakh.
# ------------
# Retrieving Results for Index 284: burica.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 285: villamartin.
# ------------
# Retrieving Results for Index 286: sucua.
# ------------
# Retrieving Results for Index 287: biltine.
# ------------
# Retrieving Results for Index 288: nemuro.
# ------------
# Retrieving Results for Index 289: el buen pastor.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 290: merritt island.
# ------------
# Retrieving Results for Index 291: sola.
# ------------
# Retrieving Results for Index 292: el cope.
# ------------
# Retrieving Results for Index 293: ancud.
# ------------
# Retrieving Results for Index 294: kilindoni.
# ------------
# Retrieving Results for Index 295: tiznit.
# ------------
# Retrieving Results for Index 296: hamilton.
# ------------
# Retrieving Results for Index 297: vila velha.
# ------------
# Retrieving Results for Index 298: arti.
# ------------
# Retrieving Results for Index 299: san quintin.
# ------------
# Retrieving Results for Index 300: krasnoselkup.
# ------------
# Retrieving Results for Index 301: lahij.
# ------------
# Retrieving Results for Index 302: kanata.
# ------------
# Retrieving Results for Index 303: rochelle.
# ------------
# Retrieving Results for Index 304: srednekolymsk.
# ------------
# Retrieving Results for Index 305: rogovatoye.
# ------------
# Retrieving Results for Index 306: bubaque.
# ------------
# Retrieving Results for Index 307: bata.
# ------------
# Retrieving Results for Index 308: podporozhye.
# ------------
# Retrieving Results for Index 309: esfahan.
# ------------
# Retrieving Results for Index 310: chanute.
# ------------
# Retrieving Results for Index 311: turochak.
# ------------
# Retrieving Results for Index 312: omboue.
# ------------
# Retrieving Results for Index 313: adrar.
# ------------
# Retrieving Results for Index 314: caravelas.
# ------------
# Retrieving Results for Index 315: sao joao da barra.
# ------------
# Retrieving Results for Index 316: sondrio.
# ------------
# Retrieving Results for Index 317: neuchatel.
# ------------
# Retrieving Results for Index 318: makambako.
# ------------
# Retrieving Results for Index 319: taksimo.
# ------------
# Retrieving Results for Index 320: puerto escondido.
# ------------
# Retrieving Results for Index 321: chardara.
# ------------
# Retrieving Results for Index 322: husavik.
# ------------
# Retrieving Results for Index 323: ust-kuyga.
# ------------
# Retrieving Results for Index 324: axim.
# ------------
# Retrieving Results for Index 325: belmonte.
# ------------
# Retrieving Results for Index 326: pauini.
# ------------
# Retrieving Results for Index 327: bonga.
# ------------
# Retrieving Results for Index 328: arraial do cabo.
# ------------
# Retrieving Results for Index 329: los llanos de aridane.
# ------------
# Retrieving Results for Index 330: mahebourg.
# ------------
# Retrieving Results for Index 331: srivilliputtur.
# ------------
# Retrieving Results for Index 332: hasaki.
# ------------
# Retrieving Results for Index 333: asayita.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 334: nongstoin.
# ------------
# Retrieving Results for Index 335: ust-bolsheretsk.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 336: lumphat.
# ------------
# Retrieving Results for Index 337: najran.
# ------------
# Retrieving Results for Index 338: fethiye.
# ------------
# Retrieving Results for Index 339: katobu.
# ------------
# Retrieving Results for Index 340: leningradskiy.
# ------------
# Retrieving Results for Index 341: makaha.
# ------------
# Retrieving Results for Index 342: phalaborwa.
# ------------
# Retrieving Results for Index 343: makung.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 344: guanica.
# ------------
# Retrieving Results for Index 345: kavieng.
# ------------
# Retrieving Results for Index 346: ankazobe.
# ------------
# Retrieving Results for Index 347: goroka.
# ------------
# Retrieving Results for Index 348: guerrero negro.
# ------------
# Retrieving Results for Index 349: manzil tamim.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 350: gazalkent.
# ------------
# Retrieving Results for Index 351: lavrentiya.
# ------------
# Retrieving Results for Index 352: ruatoria.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 353: warqla.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 354: nguru.
# ------------
# Retrieving Results for Index 355: pangai.
# ------------
# Retrieving Results for Index 356: ryotsu.
# ------------
# Retrieving Results for Index 357: makungu.
# ------------
# Retrieving Results for Index 358: richards bay.
# ------------
# Retrieving Results for Index 359: jaca.
# ------------
# Retrieving Results for Index 360: vaitupu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 361: paamiut.
# ------------
# Retrieving Results for Index 362: bathsheba.
# ------------
# Retrieving Results for Index 363: sentyabrskiy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 364: graaff-reinet.
# ------------
# Retrieving Results for Index 365: nago.
# ------------
# Retrieving Results for Index 366: olavarria.
# ------------
# Retrieving Results for Index 367: atikokan.
# ------------
# Retrieving Results for Index 368: faro.
# ------------
# Retrieving Results for Index 369: shellbrook.
# ------------
# Retrieving Results for Index 370: byron bay.
# ------------
# Retrieving Results for Index 371: ottumwa.
# ------------
# Retrieving Results for Index 372: ada.
# ------------
# Retrieving Results for Index 373: beringovskiy.
# ------------
# Retrieving Results for Index 374: ponta delgada.
# ------------
# Retrieving Results for Index 375: puerto madero.
# ------------
# Retrieving Results for Index 376: tungkang.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 377: progreso.
# ------------
# Retrieving Results for Index 378: effingham.
# ------------
# Retrieving Results for Index 379: chirongui.
# ------------
# Retrieving Results for Index 380: kankaanpaa.
# ------------
# Retrieving Results for Index 381: vredendal.
# ------------
# Retrieving Results for Index 382: batemans bay.
# ------------
# Retrieving Results for Index 383: lata.
# ------------
# Retrieving Results for Index 384: saint anthony.
# ------------
# Retrieving Results for Index 385: kampong cham.
# ------------
# Retrieving Results for Index 386: renqiu.
# ------------
# Retrieving Results for Index 387: gaomi.
# ------------
# Retrieving Results for Index 388: gayny.
# ------------
# Retrieving Results for Index 389: carnarvon.
# ------------
# Retrieving Results for Index 390: nantucket.
# ------------
# Retrieving Results for Index 391: ust-tarka.
# ------------
# Retrieving Results for Index 392: kuldur.
# ------------
# Retrieving Results for Index 393: grand baie.
# ------------
# Retrieving Results for Index 394: samarai.
# ------------
# Retrieving Results for Index 395: velluru.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 396: meyungs.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 397: grand gaube.
# ------------
# Retrieving Results for Index 398: bonfim.
# ------------
# Retrieving Results for Index 399: isiro.
# ------------
# Retrieving Results for Index 400: sosnogorsk.
# ------------
# Retrieving Results for Index 401: buraydah.
# ------------
# Retrieving Results for Index 402: abalak.
# ------------
# Retrieving Results for Index 403: huanuco.
# ------------
# Retrieving Results for Index 404: copiapo.
# ------------
# Retrieving Results for Index 405: north myrtle beach.
# ------------
# Retrieving Results for Index 406: morococha.
# ------------
# Retrieving Results for Index 407: chama.
# ------------
# Retrieving Results for Index 408: north augusta.
# ------------
# Retrieving Results for Index 409: muzhi.
# ------------
# Retrieving Results for Index 410: tabulbah.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 411: buchanan.
# ------------
# Retrieving Results for Index 412: troitsko-pechorsk.
# ------------
# Retrieving Results for Index 413: praia.
# ------------
# Retrieving Results for Index 414: samfya.
# ------------
# Retrieving Results for Index 415: fengcheng.
# ------------
# Retrieving Results for Index 416: carnot.
# ------------
# Retrieving Results for Index 417: isangel.
# ------------
# Retrieving Results for Index 418: alofi.
# ------------
# Retrieving Results for Index 419: nizhnyaya tavda.
# ------------
# Retrieving Results for Index 420: mago.
# ------------
# Retrieving Results for Index 421: hay river.
# ------------
# Retrieving Results for Index 422: kamiiso.
# ------------
# Retrieving Results for Index 423: ossora.
# ------------
# Retrieving Results for Index 424: broken hill.
# ------------
# Retrieving Results for Index 425: bendigo.
# ------------
# Retrieving Results for Index 426: tigil.
# ------------
# Retrieving Results for Index 427: dicabisagan.
# ------------
# Retrieving Results for Index 428: macae.
# ------------
# Retrieving Results for Index 429: codrington.
# ------------
# Retrieving Results for Index 430: amderma.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 431: princeton.
# ------------
# Retrieving Results for Index 432: ilam.
# ------------
# Retrieving Results for Index 433: tsihombe.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 434: luwuk.
# ------------
# Retrieving Results for Index 435: iqaluit.
# ------------
# Retrieving Results for Index 436: ugoofaaru.
# ------------
# Retrieving Results for Index 437: cap malheureux.
# ------------
# Retrieving Results for Index 438: esperance.
# ------------
# Retrieving Results for Index 439: manggar.
# ------------
# Retrieving Results for Index 440: soe.
# ------------
# Retrieving Results for Index 441: deputatskiy.
# ------------
# Retrieving Results for Index 442: chlorakas.
# ------------
# Retrieving Results for Index 443: maki.
# ------------
# Retrieving Results for Index 444: yar-sale.
# ------------
# Retrieving Results for Index 445: barcelos.
# ------------
# Retrieving Results for Index 446: ngunguru.
# ------------
# Retrieving Results for Index 447: colac.
# ------------
# Retrieving Results for Index 448: rocha.
# ------------
# Retrieving Results for Index 449: umzimvubu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 450: beoumi.
# ------------
# Retrieving Results for Index 451: vengerovo.
# ------------
# Retrieving Results for Index 452: nouadhibou.
# ------------
# Retrieving Results for Index 453: vanimo.
# ------------
# Retrieving Results for Index 454: glenluce.
# ------------
# Retrieving Results for Index 455: shenjiamen.
# ------------
# Retrieving Results for Index 456: kuche.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 457: kaeo.
# ------------
# Retrieving Results for Index 458: napanee.
# ------------
# Retrieving Results for Index 459: harper.
# ------------
# Retrieving Results for Index 460: port lincoln.
# ------------
# Retrieving Results for Index 461: sitka.
# ------------
# Retrieving Results for Index 462: santa rosa.
# ------------
# Retrieving Results for Index 463: sept-iles.
# ------------
# Retrieving Results for Index 464: kijang.
# ------------
# Retrieving Results for Index 465: belaya gora.
# ------------
# Retrieving Results for Index 466: pandan.
# ------------
# Retrieving Results for Index 467: surt.
# ------------
# Retrieving Results for Index 468: makakilo city.
# ------------
# Retrieving Results for Index 469: missungwi.
# ------------
# Retrieving Results for Index 470: neuruppin.
# ------------
# Retrieving Results for Index 471: balkhash.
# ------------
# Retrieving Results for Index 472: toliary.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 473: ust-tsilma.
# ------------
# Retrieving Results for Index 474: pemba.
# ------------
# Retrieving Results for Index 475: santa fe.
# ------------
# Retrieving Results for Index 476: linhares.
# ------------
# Retrieving Results for Index 477: mys shmidta.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 478: fort nelson.
# ------------
# Retrieving Results for Index 479: coihaique.
# ------------
# Retrieving Results for Index 480: maykain.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 481: bjornevatn.
# ------------
# Retrieving Results for Index 482: ormara.
# ------------
# Retrieving Results for Index 483: lardos.
# ------------
# Retrieving Results for Index 484: la palma.
# ------------
# Retrieving Results for Index 485: san vicente.
# ------------
# Retrieving Results for Index 486: mandalgovi.
# ------------
# Retrieving Results for Index 487: port-gentil.
# ------------
# Retrieving Results for Index 488: phalodi.
# ------------
# Retrieving Results for Index 489: kenai.
# ------------
# Retrieving Results for Index 490: karatsu.
# ------------
# Retrieving Results for Index 491: coremas.
# ------------
# Retrieving Results for Index 492: itoman.
# ------------
# Retrieving Results for Index 493: solovetskiy.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 494: matara.
# ------------
# Retrieving Results for Index 495: koscierzyna.
# ------------
# Retrieving Results for Index 496: dumas.
# ------------
# Retrieving Results for Index 497: ixtapa.
# ------------
# Retrieving Results for Index 498: hofn.
# ------------
# Retrieving Results for Index 499: paraiso.
# ------------
# Retrieving Results for Index 500: mangrol.
# ------------
# Retrieving Results for Index 501: yefira.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 502: wasilla.
# ------------
# Retrieving Results for Index 503: hualmay.
# ------------
# Retrieving Results for Index 504: kuytun.
# ------------
# Retrieving Results for Index 505: pajapan.
# ------------
# Retrieving Results for Index 506: channagiri.
# ------------
# Retrieving Results for Index 507: bengkulu.
# ------------
# Retrieving Results for Index 508: aykhal.
# ------------
# Retrieving Results for Index 509: salyan.
# ------------
# Retrieving Results for Index 510: adre.
# ------------
# Retrieving Results for Index 511: huaicheng.
# ------------
# Retrieving Results for Index 512: araguaina.
# ------------
# Retrieving Results for Index 513: labutta.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 514: bell ville.
# ------------
# Retrieving Results for Index 515: fuyu.
# ------------
# Retrieving Results for Index 516: general cepeda.
# ------------
# Retrieving Results for Index 517: amparafaravola.
# ------------
# Retrieving Results for Index 518: las cruces.
# ------------
# Retrieving Results for Index 519: beian.
# ------------
# Retrieving Results for Index 520: grindavik.
# ------------
# Retrieving Results for Index 521: general pico.
# ------------
# Retrieving Results for Index 522: gizo.
# ------------
# Retrieving Results for Index 523: mareeba.
# ------------
# Retrieving Results for Index 524: khandyga.
# ------------
# Retrieving Results for Index 525: vostochnyy.
# ------------
# Retrieving Results for Index 526: chimore.
# ------------
# Retrieving Results for Index 527: mecca.
# ------------
# Retrieving Results for Index 528: campanha.
# ------------
# Retrieving Results for Index 529: salalah.
# ------------
# Retrieving Results for Index 530: el alto.
# ------------
# Retrieving Results for Index 531: soyo.
# ------------
# Retrieving Results for Index 532: mitsamiouli.
# ------------
# Retrieving Results for Index 533: lyuban.
# ------------
# Retrieving Results for Index 534: cheremukhovo.
# ------------
# Retrieving Results for Index 535: ambon.
# ------------
# Retrieving Results for Index 536: omsukchan.
# ------------
# Retrieving Results for Index 537: poum.
# ------------
# Retrieving Results for Index 538: asau.
# ------------
# Retrieving Results for Index 539: vila franca do campo.
# ------------
# Retrieving Results for Index 540: suntar.
# ------------
# Retrieving Results for Index 541: marawi.
# ------------
# Retrieving Results for Index 542: noumea.
# ------------
# Retrieving Results for Index 543: tokur.
# ------------
# Retrieving Results for Index 544: durant.
# ------------
# Retrieving Results for Index 545: aljezur.
# ------------
# Retrieving Results for Index 546: arman.
# ------------
# Retrieving Results for Index 547: limoges.
# ------------
# Retrieving Results for Index 548: san luis.
# ------------
# Retrieving Results for Index 549: middle island.
# ------------
# Retrieving Results for Index 550: lingao.
# ------------
# Retrieving Results for Index 551: chulman.
# ------------
# Retrieving Results for Index 552: morant bay.
# ------------
# Retrieving Results for Index 553: saryg-sep.
# ------------
# Retrieving Results for Index 554: altamont.
# ------------
# Retrieving Results for Index 555: maniitsoq.
# ------------
# Retrieving Results for Index 556: marcona.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 557: wad rawah.
# ------------
# Retrieving Results for Index 558: mae sot.
# ------------
# Retrieving Results for Index 559: avera.
# ------------
# Retrieving Results for Index 560: porto novo.
# ------------
# Retrieving Results for Index 561: padang.
# ------------
# Retrieving Results for Index 562: taltal.
# ------------
# Retrieving Results for Index 563: lakatoro.
# ------------
# Retrieving Results for Index 564: salinopolis.
# ------------
# Retrieving Results for Index 565: villa guerrero.
# ------------
# Retrieving Results for Index 566: zaton.
# ------------
# Retrieving Results for Index 567: mudyuga.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 568: paita.
# ------------
# Retrieving Results for Index 569: sangmelima.
# ------------
# Retrieving Results for Index 570: sulina.
# ------------
# Retrieving Results for Index 571: jhudo.
# ------------
# Retrieving Results for Index 572: fostoria.
# ------------
# Retrieving Results for Index 573: buala.
# ------------
# Retrieving Results for Index 574: roros.
# ------------
# Retrieving Results for Index 575: le port.
# ------------
# Retrieving Results for Index 576: yaring.
# ------------
# Retrieving Results for Index 577: manyana.
# ------------
# Retrieving Results for Index 578: gimli.
# ------------
# Retrieving Results for Index 579: massakory.
# ------------

# %%
print(Error_count)

cities_df.index.names = ["city_ID"]

#cities_df
# Out:
# 53

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.to_csv('/Users/jenniferramsey/hw/Python_API/output_data/cities.csv', index=True)

# %%
cities_df.head()

#cities_df['wind_speed'].min(), cities_df['wind_speed'].max()
# Out:
# (0.45, 33.26)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_axis = cities_df['latitude']
y_axis = cities_df['max_temp']

plt.scatter(x_axis, y_axis, facecolors="red", edgecolors="black", alpha=1.0)
plt.xlim(-60, 90)
plt.ylim((cities_df['max_temp'].min() - 10), (cities_df['max_temp'].max() + 10))
plt.title('Latitude vs Max Temperature (F)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.show()

##Measuring the relationship between Latitude (Distance from the equator) and the Max Temp for the region.
##The closer the city is to the equator (lat = 0), the higher the temperature.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_axis = cities_df['latitude']
y_axis = cities_df['humidity']

plt.scatter(x_axis, y_axis, facecolors="red", edgecolors="black", alpha=1.0)
plt.xlim(-60, 90)
plt.ylim((cities_df['humidity'].min() - 10), (cities_df['humidity'].max() + 10))
plt.title('Latitude vs Humidity %')
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.show()

##measuring the relationship between Latitude and Humidity.
##there does not appear to be any strong relationship between latitude and humidity.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_axis = cities_df['latitude']
y_axis = cities_df['cloudiness']

plt.scatter(x_axis, y_axis, facecolors="red", edgecolors="black", alpha=1.0)
plt.xlim(-60, 90)
plt.ylim((cities_df['cloudiness'].min() - 10), (cities_df['cloudiness'].max() + 10))
plt.title('Latitude vs Cloudiness %')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.show()

#measuring the relationship between latitude and cloudiness.
##there does not appear to be a strong relationship between latitude and cloudiness

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_axis = cities_df['latitude']
y_axis = cities_df['wind_speed']

plt.scatter(x_axis, y_axis, facecolors="red", edgecolors="black", alpha=1.0)
plt.xlim(-60, 90)
plt.ylim((cities_df['wind_speed'].min() - 10), (cities_df['wind_speed'].max() + 10))
plt.title('Latitude vs Wind Speed MPH')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed MPH')
plt.show()

#measuring the relationship between latitude and wind speed.
##there does not appear to be a significant relationship between latitude and wind speed,
#but the data may support stronger winds closer to the poles

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = cities_df[cities_df.latitude >= 0]
#northern_hemisphere

southern_hemisphere = cities_df[cities_df.latitude < 0]
#southern_hemisphere

#southern_hemisphere['latitude'].max(), northern_hemisphere['latitude'].min()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = northern_hemisphere['latitude']
y_axis = northern_hemisphere['max_temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis, facecolors="red", edgecolors="black", alpha=1.0)
plt.xlim(-10, 90)
plt.ylim((northern_hemisphere['max_temp'].min() - 10), (northern_hemisphere['max_temp'].max() + 10))
plt.plot(x_axis,regress_values,"b-")
plt.annotate(line_eq,(6,10),fontsize=15,color="blue")
plt.title('Northern Latitude vs Max Temperature (F)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.show()

##measuring the relationship between latitude and temperature in the NORTHERN hemisphere.
##There is a relationship of decrease of temperature as latitude increases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = southern_hemisphere['latitude']
y_axis = southern_hemisphere['max_temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis, facecolors="blue", edgecolors="black", alpha=1.0)
plt.xlim(-60, 10)
plt.ylim((southern_hemisphere['max_temp'].min() - 10), (southern_hemisphere['max_temp'].max() + 10))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.title('Southern Latitude vs Max Temperature (F)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.show()

##measuring the relationship between latitude and temperature in the SOUTHERN hemisphere.
##There is a relationship of decrease of temperature as latitude decreases,
##though not as sharply as in the north.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = northern_hemisphere['latitude']
y_axis = northern_hemisphere['humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis, facecolors="red", edgecolors="black", alpha=1.0)
plt.xlim(-10, 90)
plt.ylim((northern_hemisphere['humidity'].min() - 10), (northern_hemisphere['humidity'].max() + 10))
plt.plot(x_axis,regress_values,"b-")
plt.annotate(line_eq,(6,10),fontsize=15,color="blue")
plt.title('Northern Latitude vs Humidity (%)')
plt.xlabel('Latitude')
plt.ylabel('Humididty (%)')
plt.show()
##measuring the relationship between Latitude and Humidity in the NORTHERN hemisphere.
##regression indicates that there is some evidence that as latitude rises, Humdity rises slightly.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = southern_hemisphere['latitude']
y_axis = southern_hemisphere['humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis, facecolors="blue", edgecolors="black", alpha=1.0)
plt.xlim(-60, 10)
plt.ylim((southern_hemisphere['humidity'].min() - 10), (southern_hemisphere['humidity'].max() + 10))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.title('Southern Latitude vs Humidity (%)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()

##measuring the relationship between Latitude and Humidity in the SOUTHERN hemisphere.
##regression indicates that there is some evidence that as latitude rises, Humdity rises slightly.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = northern_hemisphere['latitude']
y_axis = northern_hemisphere['cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis, facecolors="red", edgecolors="black", alpha=1.0)
plt.xlim(-10, 90)
plt.ylim((northern_hemisphere['cloudiness'].min() - 10), (northern_hemisphere['cloudiness'].max() + 10))
plt.plot(x_axis,regress_values,"b-")
plt.annotate(line_eq,(75,10),fontsize=15,color="blue")
plt.title('Northern Latitude vs Cloudiness (%)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()

##measuring the relationship between Latitude and Cloudiness in the NORTHERN hemisphere.
##regression indicates that there is some evidence that as latitude rises, cloudiness rises slightly.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = southern_hemisphere['latitude']
y_axis = southern_hemisphere['cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis, facecolors="blue", edgecolors="black", alpha=1.0)
plt.xlim(-60, 10)
plt.ylim((southern_hemisphere['cloudiness'].min() - 10), (southern_hemisphere['cloudiness'].max() + 10))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.title('Southern Latitude vs Cloudiness (%)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()

##measuring the relationship between Latitude and Cloudiness in the SOUTHERN hemisphere.
##regression indicates that there is some evidence that as latitude rises, cloudiness rises slightly.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = northern_hemisphere['latitude']
y_axis = northern_hemisphere['wind_speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis, facecolors="red", edgecolors="black", alpha=1.0)
plt.xlim(-10, 90)
plt.ylim((northern_hemisphere['wind_speed'].min() - 10), (northern_hemisphere['wind_speed'].max() + 10))
plt.plot(x_axis,regress_values,"b-")
plt.annotate(line_eq,(75,10),fontsize=15,color="blue")
plt.title('Northern Latitude vs Wind Speed (MPH)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = southern_hemisphere['latitude']
y_axis = southern_hemisphere['wind_speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis, facecolors="blue", edgecolors="black", alpha=1.0)
plt.xlim(-60, 10)
plt.ylim((southern_hemisphere['wind_speed'].min() - 10), (southern_hemisphere['wind_speed'].max() + 10))
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.title('Southern Latitude vs Wind Speed (MPH)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.show()
